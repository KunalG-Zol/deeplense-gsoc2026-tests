# %%
import numpy as np

# %% [markdown]
# ## Checking the dimensions of the images

# %%
img_arr = np.load('dataset/dataset/train/sphere/3.npy')

# %%
np.shape(img_arr)
# Out:
# (1, 150, 150)

# %%
img_arr
# Out:
# array([[[0.01369863, 0.01141553, 0.00913242, ..., 0.00570776,
#          0.01027397, 0.00799087],
#         [0.01027397, 0.00799087, 0.00799087, ..., 0.01255708,
#          0.00570776, 0.01141553],
#         [0.00456621, 0.00342466, 0.01141553, ..., 0.00799087,
#          0.01141553, 0.01141553],
#         ...,
#         [0.00570776, 0.00684932, 0.00228311, ..., 0.01255708,
#          0.00570776, 0.00570776],
#         [0.01369863, 0.01369863, 0.00342466, ..., 0.01027397,
#          0.01484018, 0.01369863],
#         [0.00913242, 0.00913242, 0.00570776, ..., 0.00799087,
#          0.01027397, 0.01141553]]], shape=(1, 150, 150))

# %%
import matplotlib.pyplot as plt

# %%
gamma_corrected = np.power(img_arr[0] + 1e-8, 0.2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
im1 = axes[0].imshow(img_arr[0], cmap='magma')
axes[0].set_title('Raw Min-Max Image\n(What the network currently sees)')
axes[0].axis('off')
fig.colorbar(im1, ax=axes[0], fraction=0.046, pad=0.04)

# Plot 2: The Transformed Image
im2 = axes[1].imshow(gamma_corrected, cmap='magma')
axes[1].set_title(f'Gamma Corrected\n(Revealing the hidden substructure)')
axes[1].axis('off')
fig.colorbar(im2, ax=axes[1], fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
