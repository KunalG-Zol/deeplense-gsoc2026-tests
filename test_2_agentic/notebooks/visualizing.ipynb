# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.load('../agent/outputs/Model_III/no_sub/no_sub_sim_86162294960525634559037825785987517078.npy', allow_pickle=True)

# %%
np.shape(arr)
# Out:
# (64, 64)

# %%
plt.imshow(arr, cmap='magma')
plt.colorbar()
plt.title('Lensed image')
plt.show()

# %%
plt.imshow(arr, cmap='magma')
plt.colorbar()
plt.title('Lensed image')
plt.show()
