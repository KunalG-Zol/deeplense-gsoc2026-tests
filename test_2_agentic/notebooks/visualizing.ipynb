# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.load('../agent/outputs/Model_II/cdm/cdm_sim_279840962413770860547471529539634671305.npy', allow_pickle=True)

# %%
np.shape(arr[0])
# Out:
# (64,)

# %%
plt.imshow(arr, cmap='magma')
plt.colorbar(label='Flux')
plt.title('Lensed image')
plt.show()
